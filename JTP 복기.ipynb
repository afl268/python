# %%
a = 123 # 정수
a = 1.2 # 실수
a = 4.24E10 # 실수(지수)
a = 0o177 # 8진수
a = 0x8ff # 16진수

# %%
a = 3
b = 4
a + b # 7
a * b # 12
a / b # 0.75
a ** b # 81(a의 b제곱)
# Out:
# 81

# %%
7 % 3 # 1(나눗셈 후 나머지를 반환)
3 % 7 # 3

7 / 4 # 1.75
7 // 4 # 1(나눗셈 후 몫을 반환)
# Out:
# 1

# %%
"Hello World"
'Hello World'
"""Life is python"""
'''Life is python'''
# Out:
# 'Hello World'

# %%
food = "Python's nihehe"
# food = 'Python's nihehe' # ERROR
food
# Out:
# "Python's nihehe"

# %%
say = '"Python is nihehe" he says.'
food = 'Python|s nihehe'
say = "|"Python is nihehe.|" he says."
# Out:
#   File "<ipython-input-7-2663acbcd12b>", line 3
#     say = "|"Python is nihehe.|" he says."
#              ^
# SyntaxError: invalid syntax

# %%
multiline = "Sleeping\n Sleep"
multiline # ....
# Out:
# 'Sleeping\n Sleep'

# %%
head = "Python"
tail = " nihehe"
head + tail # 문자열 연결
# Out:
# 'Python nihehe'

# %%
a = "nihehe"
a * 2 # 문자열 곱하기
# Out:
# 'nihehenihehe'

# %%
a = "LIfe is nihehe"
len(a) # 문자열 길이 구하기
# Out:
# 14

# %%
a = "Life is nihehe..."
a[2] # 문자열 인덱싱
# Out:
# 'f'

# %%
a[-4]
# Out:
# 'e'

# %%
a = "Life is nihehe..."
a[0:4] # 문자열 슬라이싱, 끝번호는 포함하지 않음 , 'Life'
a[5:7] # 'is'
# Out:
# 'is'

# %%
b = a[:4] # Life
c = a[4:] # is nihehe...
b + c
# Out:
# 'Life is nihehe...'

# %%
a = "niheha"
# a[5] = 'e'   'str' object does not support item assignment
a[:5] + 'e'
# Out:
# 'nihehe'

# %%
"I eat %d coke-can" % 3 # if num, use %d 
"I eat %s coke-can" % "five" # if str, use %s
# Out:
# 'I eat five coke-can'

# %%
number = 5
"I eat %d coke-can" % number # 숫자 값을 나타내는 변수 대입
# Out:
# 'I eat 5 coke-can'

# %%
number = 10
day = "three"
"i ate %d apples. so sleep %s days." % (number,day) # 두 변수 대입
# Out:
# 'i ate 10 apples. so sleep three days.'

# %%
"rate is %s" % 32156156448487.151
# Out:
# 'rate is 32156156448487.152'

# %%
# "Error is %d%." % 98   incomplete format
"Error is %d%%." % 98
# Out:
# 'Error is 98%.'

# %%
"%10s" % "hi"
# Out:
# '        hi'

# %%
"%-10sjane." % 'hi'
# Out:
# 'hi        jane.'

# %%
"%0.4f" % 3.14926 # 소수점 4자리까지
# Out:
# '3.1493'

# %%
"i eat {0} apples.".format(3) # format 함수
# Out:
# 'i eat 3 apples.'

# %%
"i eat {0} apples.".format("six")
# Out:
# 'i eat six apples.'

# %%
number = 3
"i eat {0} apples.".format(number)
# Out:
# 'i eat 3 apples.'

# %%
number = 3
day = "?"
"i eat {0} apples. so sleep {1} days.".format(number,day)
# Out:
# 'i eat 3 apples. so sleep ? days.'

# %%
"I ate {0} apples. so I was sick for {day} days.".format(10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
y = 3.141592
"{0:0.4f}".format(y)
# Out:
# '3.1416'

# %%
name = '사람'
age = 22
f'{name},{age}' # f 문자열 포매팅
# Out:
# '사람,22'

# %%
f'{age+1}'
# Out:
# '23'

# %%
a = "nihehe"
a.count('e') # 문자열 중 문자 b의 개수를 돌려줌
# Out:
# 2

# %%
a.find('e') # 'e'의 위치를 알려줌 , 처음으로 나온 위치를 반환(없으면 -1)
# Out:
# 3

# %%
a.index('e')  # 'e'의 위치를 알려줌, 처음으로 나온 위치 반환(없으면 ERROR)
# Out:
# 3

# %%
",".join('abcdefg') # 문자열 삽입(join)
# Out:
# 'a,b,c,d,e,f,g'

# %%
a = "nihehe"
a.upper() # 소문자 -> 대문자
# Out:
# 'NIHEHE'

# %%
a = "NIHEHE"
a.lower() # 대문자 -> 소문자
# Out:
# 'nihehe'

# %%
a = "Life is nihehe"
a.replace("Life", "solcen") # 문자열 바꾸기(replace)
# Out:
# 'solcen is nihehe'

# %%
a = "Life is nihehe"
a.split() # 문자열 나누기(split)
# Out:
# ['Life', 'is', 'nihehe']
