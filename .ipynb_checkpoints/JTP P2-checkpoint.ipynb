# %%
국어 = 80
영어 = 75
수학 = 55

평균 = (국어 + 영어+ 수학) / 3
평균
# Out:
# 70.0

# %%
13 % 2
# Out:
# 1

# %%
홍길동 = "881120-1068234"
홍길동[:6]
# Out:
# '881120'

# %%
홍길동[7:]
# Out:
# '1068234'

# %%
pin = "881120-1068234"
pin[7:8]
# Out:
# '1'

# %%
a = "a:b:c:d"
a.replace(":","#")
# Out:
# 'a#b#c#d'

# %%
a = [1, 3, 5, 4, 2]
a.sort()
a.reverse()
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = ['Life', 'is', 'too', 'short']
b = " ".join(a)
b
# Out:
# 'Life is too short'

# %%
a = (1, 2, 3)
b = (4,)
a + b
# Out:
# (1, 2, 3, 4)

# %%
a = dict()
a
a[[1]] = 'python'
# 변하는 값이기 때문에
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-2ab547bcd03c> in <module>
#       1 a = dict()
#       2 a
# ----> 3 a[[1]] = 'python'
#
# TypeError: unhashable type: 'list'

# %%
a = {'A':90, 'B':80, 'C':70} 
a.pop('B')
# Out:
# 80

# %%
a = [1, 1, 1, 2, 2, 3, 3, 3, 4, 4, 5]
b = set(a)
b
# Out:
# {1, 2, 3, 4, 5}

# %%
a = b = [1, 2, 3]
a[1] = 4
print(b) # b는 a기 때문
# Out:
# [1, 4, 3]
