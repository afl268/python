# %%
# 정수형
a = 123
a = -178
a = 0

# 실수형

a = 1.2
a = -3.45

# 8,16 진수 스킵

# 사칙연산

a = 3
b = 4
a + b
# Out:
# 7

# %%
a * b
# Out:
# 12

# %%
a / b
# Out:
# 0.75

# %%
# x의 y제곱을 나타내는 ** 연산자
a = 3
b = 4
a ** b
# Out:
# 81

# %%
# 나눗셈 후 나머지를 반환하는 % 연산자
7 % 3
# Out:
# 1

# %%
3 % 7
# Out:
# 3

# %%
# 나눗셈 후 몫을 반환하는 // 연산자
7 // 4
# Out:
# 1
