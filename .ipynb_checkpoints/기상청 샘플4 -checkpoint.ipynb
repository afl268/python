# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
matplotlib.rc('axes',unicode_minus = False)
matplotlib.rc('font',family = 'Malgun Gothic')

# %%
mydata = pd.read_csv('C:/Users/emoot/data/mydata.csv')
mydata[['HM_AVG']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002647ACBEFD0>]],
#       dtype=object)

# %%
plt.figure(figsize=(10,5))
sns.distplot(mydata.HM_AVG, kde = False)

# %%
mydata=pd.read_csv('C:/Users/emoot/data/mydata.csv')
mydata.boxplot(column='RN_DAY')

# %%
plt.scatter(mydata['RN_DAY'],
mydata['CA_TOT'],color='b', marker='o')
plt.xlabel('RN_DAY')
plt.ylabel('CA_TOT')
# Out:
# Text(0, 0.5, 'CA_TOT')
