# %%
# while문 기본 구조
treeHit = 0
while treeHit < 5:
    treeHit = treeHit + 1
    print("나무를 %d번 찍음" % treeHit)
    if treeHit == 5:
        print("나무 넘어간다")
# Out:
# 나무를 1번 찍음
# 나무를 2번 찍음
# 나무를 3번 찍음
# 나무를 4번 찍음
# 나무를 5번 찍음
# 나무 넘어간다

# %%
#while문 만들기
prompt= """
1. Add
2. Del
3. List
4. Quit

Enter number = """

# %%
number = 0
while number != 4:
    print(prompt)
    number = int(input())
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number =
# 2
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number =
# 4

# %%
# while문 강제로 빠져나가기
coffee = 10
money = 300
while money:
    print("돈을 받았으니 커피를 준다.")
    coffee = coffee - 1
    print("남은 커피의 양은 %d개 이다." % coffee)
    if coffee == 0:
        print("커피가 다 떨어졌다. 영업종료")
        break
# Out:
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 9개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 8개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 7개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 6개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 5개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 4개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 3개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 2개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 1개 이다.
# 돈을 받았으니 커피를 준다.
# 남은 커피의 양은 0개 이다.
# 커피가 다 떨어졌다. 영업종료

# %%
coffee = 2
while True:
    money = int(input("돈을 투입해주세요 : "))
    if money == 300:
        print("커피를 준다.")
        coffee = coffee -1
    elif money > 300:
        print("거스름돈 %d를 주고 커피를 준다" % (money - 300))
        coffee = coffee - 1
    else:
        print("돈을 다시 돌려주고 커피를 주지 않는다.")
        print("남은 커피의 양은 %d개 이다" % coffee)
    if coffee == 0:
        print("커피가 다 떨어졌다. 영업종료.")
        break
# Out:
# 돈을 투입해주세요 : 300
# 커피를 준다.
# 돈을 투입해주세요 : 250
# 돈을 다시 돌려주고 커피를 주지 않는다.
# 남은 커피의 양은 1개 이다
# 돈을 투입해주세요 : 400
# 거스름돈 100를 주고 커피를 준다
# 커피가 다 떨어졌다. 영업종료.

# %%
# while문의 맨 처음으로 돌아가기
a = 0
while a < 10:
    a = a + 1
    if a % 2 == 0: continue
    print(a)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#무한 루프
while True:
    print("Ctrl+C를 눌러야 도망 갈 수 있음.")
