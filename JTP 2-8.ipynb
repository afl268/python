# %%
# 변수를 만들 땐 = (assignment) 기호 사용
# c나 java에선 변수 만들 때 자료형 직접 지정
a = 1
b = "python"
c = [1, 2, 3]

# %%
# a 변수가 가르키는 메모리의 주소
a = [1, 2, 3]
id(a)
# Out:
# 2011524735552

# %%
a = [1, 2, 3]
b = a

id(a)
# Out:
# 2011525183488

# %%
id(b) # a와 주소 같음
# Out:
# 2011525183488

# %%
a is b
# Out:
# True

# %%
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 4, 3]

# %%
a = [1, 2, 3]
b = a[:] # 리스트 전체를 가르킴
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b # b 리스트에는 영향이 없음
# Out:
# [1, 2, 3]

# %%
from copy import copy as cp
a = [1, 2, 3]
b = cp(a)

# %%
b is a # b와 a의 객체는 서로 다름
# Out:
# False

# %%
# 변수를 만드는 여러 방법
a, b = ('python', 'life')

# %%
(a , b) = 'python', 'life'

# %%
[a,b] = ['python', 'life']

# %%
a = b = 'python'

# %%
a = 3
b = 5
a, b = b, a # 값 교환
a
# Out:
# 5

# %%
b
# Out:
# 3
