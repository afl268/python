# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import numpy as np
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
matplotlib.rc('axes',unicode_minus = False)
matplotlib.rc('font',family = 'Malgun Gothic')

# %%
df = pd.read_csv('C:/Users/emoot/data/is1week.csv',encoding='cp949')
print(df)
# Out:
#       지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  현지기압(hPa)  \
# 0    112  인천  2022-01-19 01:00    -4.9      NaN      2.0     52     1018.8
# 1    112  인천  2022-01-19 02:00    -4.8      NaN      1.6     51     1018.5
# 2    112  인천  2022-01-19 03:00    -5.2      NaN      1.4     53     1018.5
# 3    112  인천  2022-01-19 04:00    -5.7      NaN      1.1     52     1017.9
# 4    112  인천  2022-01-19 05:00    -5.9      NaN      1.5     56     1017.4
# ..   ...  ..               ...     ...      ...      ...    ...        ...
# 139  112  인천  2022-01-24 20:00     6.1      NaN      2.2     44     1012.3
# 140  112  인천  2022-01-24 21:00     6.0      NaN      2.9     43     1012.4
# 141  112  인천  2022-01-24 22:00     5.8      NaN      2.9     44     1012.6
# 142  112  인천  2022-01-24 23:00     5.5      NaN      3.5     44     1012.4
# 143  112  인천  2022-01-25 00:00     5.1      NaN      3.0     45     1012.6
#
#      지면온도(°C)
# 0        -7.1
# 1        -7.4
# 2        -7.8
# ...

# %%
df["일시"] = pd.to_datetime(df["일시"])
df.head(5)
# Out:
#     지점 지점명                  일시  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  현지기압(hPa)  \
# 0  112  인천 2022-01-19 01:00:00    -4.9      NaN      2.0     52     1018.8
# 1  112  인천 2022-01-19 02:00:00    -4.8      NaN      1.6     51     1018.5
# 2  112  인천 2022-01-19 03:00:00    -5.2      NaN      1.4     53     1018.5
# 3  112  인천 2022-01-19 04:00:00    -5.7      NaN      1.1     52     1017.9
# 4  112  인천 2022-01-19 05:00:00    -5.9      NaN      1.5     56     1017.4
#
#    지면온도(°C)
# 0      -7.1
# 1      -7.4
# 2      -7.8
# 3      -8.0
# 4      -8.0

# %%
spot_ = "인천"
d_ = df[(df["지점명"]==spot_) & (df["일시"].dt.month==1)]
plt.figure(figsize=(10,5))
plt.title("1월 %s 지점 기온 추이" % spot_, fontsize=15)
plt.plot(d_["일시"], d_["기온(°C)"], "-", color='black', label=str(spot_))
plt.grid()
plt.legend(fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %%
spot_ = "인천"
d_ = df[(df["지점명"]==spot_) & (df["일시"].dt.month==1)]
plt.figure(figsize=(10,5))
plt.title("1월 %s 지점 지면 온도 추이" % spot_, fontsize=15)
plt.plot(d_["일시"], d_["지면온도(°C)"], "-", color='purple', label=str(spot_))
plt.grid()
plt.legend(fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %%
spot_ = "인천"
d_ = df[(df["지점명"]==spot_) & (df["일시"]<"2022-01-20")]
plt.figure(figsize=(10,5))
plt.title("시간대별 기온 추이(2022-01-20)", fontsize=15)
ax = plt.subplot(1,1,1)
ax.plot(d_["일시"],d_["기온(°C)"], "-o", color='red', label=str(spot_))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.legend(fontsize=13)
plt.grid()
plt.show()
# Out:
# <ipython-input-12-8efded13035c>:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(1,1,1)

# %%
spot_ = "인천"
d_ = df[(df["지점명"]==spot_) & (df["일시"].dt.month==1)]
plt.figure(figsize=(12,6))
plt.title("1월 %s 지점 기온,풍속 추이" % spot_, fontsize=15)
plt.xticks(rotation=90)
ax1 = plt.subplot(111)
ax2 = ax1.twinx()
a, =  ax1.plot(d_["일시"], d_["기온(°C)"], "-", color='red', label="기온(°C)")
b, = ax2.plot(d_["일시"], d_["풍속(m/s)"], "-", color='blue', label="풍속(m/s)")
p = [a, b]
ax1.legend(p, [p_.get_label() for p_ in p])
plt.show()
# Out:
# <ipython-input-6-41b4fc598aa1>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1 = plt.subplot(111)
