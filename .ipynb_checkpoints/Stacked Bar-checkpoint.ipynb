# %%
# Type A

import pandas as pd

data = [[2000, 2000, 2000, 2001, 2001, 2001, 2002, 2002, 2002],
        ['Jan', 'Feb', 'Mar', 'Jan', 'Feb', 'Mar', 'Jan', 'Feb', 'Mar'],  # 데이터 지정
        [1, 2, 3, 4, 5, 6, 7, 8, 9]]

rows = zip(data[0], data[1], data[2]) # 행 선언

headers = ['Year', 'Month', 'Value'] # 헤드명 선언

df = pd.DataFrame(list(rows), columns=headers)

df
# Out:
#    Year Month  Value
# 0  2000   Jan      1
# 1  2000   Feb      2
# 2  2000   Mar      3
# 3  2001   Jan      4
# 4  2001   Feb      5
# 5  2001   Mar      6
# 6  2002   Jan      7
# 7  2002   Feb      8
# 8  2002   Mar      9

# %%
# 피벗 : 특정 계산을 수행하기 위한 임의의 알고리즘 에 의해 먼저 선택된 행렬의 성분

pivot_df = df.pivot(index='Year', columns='Month', values='Value')
pivot_df = pivot_df[['Jan','Feb','Mar']].copy()
pivot_df
# Out:
# Month  Jan  Feb  Mar
# Year
# 2000     1    2    3
# 2001     4    5    6
# 2002     7    8    9

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Stacked Bar Chart
pivot_df.plot.bar(stacked=True, legend='reverse', figsize=(10,7))

# %%
# Type B-1 use numpy

import numpy as np

data1=[30,20,10,0,0]
data2=[20,20,20,20,0]
data3=[50,60,70,80,100]

year=["2015","2016","2017","2018","2019"]

plt.figure(figsize=(9,7))
plt.bar(year,data3,color="green",label="Python")
plt.bar(year,data2,color="yellow",bottom=np.array(data3),label="JavaScript")
plt.bar(year,data1,color="red",bottom=np.array(data3)+np.array(data2),label="C++")

plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()

# %%
# Type B-2 use pandas

years=["2015","2016","2017","2018","2019"]
data={
    "Python":[50,60,70,80,100],
    "JavaScript":[20,20,20,20,0],
    "C++":[30,20,10,0,0],
}

df=pd.DataFrame(data,index=years)

df.plot(kind="bar",stacked=True,figsize=(10,8))
plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()

# %%
df.plot(kind="bar",stacked=True,figsize=(10,8), edgecolor='#000000', linewidth=2)
plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()
