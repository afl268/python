# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
matplotlib.rc('axes',unicode_minus = False)
matplotlib.rc('font',family = 'Malgun Gothic')

# 판다스,매트랩, 시본 import
# 그래프 글씨를 선명하게 하기 위함
# 그래프에 - 표기 가능
# 맑은 고딕으로 폰트 설정해서 글자깨짐 방지

# %%
df = pd.read_csv('C:/Users/emoot/data/incheon17213.csv',encoding='cp949')
print(df)
# Out:
#     지점번호 지점명     일시  평균기온(℃)  평균최고기온(℃)  최고기온(℃)      최고기온일자  평균최저기온(℃)  \
# 0    112  인천  01-17     -0.9        2.8     10.8  2017-01-06       -4.1
# 1    112  인천  02-17      0.2        3.9     10.5  2017-02-28       -3.1
# 2    112  인천  03-17      5.8       10.3     15.6  2017-03-19        2.5
# 3    112  인천  04-17     12.4       16.8     22.5  2017-04-30        9.1
# 4    112  인천  05-17     17.6       22.3     26.8  2017-05-03       14.0
# 5    112  인천  06-17     21.7       25.7     29.4  2017-06-23       18.5
# 6    112  인천  07-17     25.8       28.6     32.5  2017-07-25       23.8
# 7    112  인천  08-17     25.4       28.3     34.0  2017-08-05       23.1
# 8    112  인천  09-17     21.9       25.5     28.7  2017-09-26       18.5
# 9    112  인천  10-17     15.7       19.9     26.0  2017-10-02       12.1
# 10   112  인천  11-17      5.9        9.9     19.2  2017-11-07        2.3
# 11   112  인천  12-17     -1.3        2.1     10.0  2017-12-03       -4.7
# ...

# %%
dm_sa = df.iloc[5:8, 3:4]
dm_s17 = dm_sa.mean()
dm_s17
# Out:
# 평균기온(℃)    24.3
# dtype: float64

# %%
dm_sb = df.iloc[17:20, 3:4]
dm_s18 = dm_sb.mean()
dm_s18
# Out:
# 평균기온(℃)    25.3
# dtype: float64

# %%
dm_sc = df.iloc[29:32, 3:4]
dm_s19 = dm_sc.mean()
dm_s19
# Out:
# 평균기온(℃)    24.4
# dtype: float64

# %%
dm_sd = df.iloc[41:44, 3:4]
dm_s20 = dm_sd.mean()
dm_s20
# Out:
# 평균기온(℃)    23.633333
# dtype: float64

# %%
dm_se = df.iloc[53:56, 3:4]
dm_s21 = dm_se.mean()
dm_s21
# Out:
# 평균기온(℃)    24.766667
# dtype: float64

# %%
data = { '연도' : ['2017','2018','2019','2020','2021'],
    '평균기온(℃)' : ['24.3','25.3','24.4','23.633333','24.766667'] ,
}

dfm = pd.DataFrame(data)
print(dfm)
# Out:
#      연도    평균기온(℃)
# 0  2017       24.3
# 1  2018       25.3
# 2  2019       24.4
# 3  2020  23.633333
# 4  2021  24.766667

# %%
dfm.to_csv("./df_summeravg.csv",index=False)

# %%
pd.read_csv('./df_summeravg.csv')
# Out:
#      연도    평균기온(℃)
# 0  2017  24.300000
# 1  2018  25.300000
# 2  2019  24.400000
# 3  2020  23.633333
# 4  2021  24.766667

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
sns.pointplot(data=dfm, x='연도', y='평균기온(℃)')

# %%
print(df)
# Out:
#     지점번호 지점명     일시  평균기온(℃)  평균최고기온(℃)  최고기온(℃)      최고기온일자  평균최저기온(℃)  \
# 0    112  인천  01-17     -0.9        2.8     10.8  2017-01-06       -4.1
# 1    112  인천  02-17      0.2        3.9     10.5  2017-02-28       -3.1
# 2    112  인천  03-17      5.8       10.3     15.6  2017-03-19        2.5
# 3    112  인천  04-17     12.4       16.8     22.5  2017-04-30        9.1
# 4    112  인천  05-17     17.6       22.3     26.8  2017-05-03       14.0
# 5    112  인천  06-17     21.7       25.7     29.4  2017-06-23       18.5
# 6    112  인천  07-17     25.8       28.6     32.5  2017-07-25       23.8
# 7    112  인천  08-17     25.4       28.3     34.0  2017-08-05       23.1
# 8    112  인천  09-17     21.9       25.5     28.7  2017-09-26       18.5
# 9    112  인천  10-17     15.7       19.9     26.0  2017-10-02       12.1
# 10   112  인천  11-17      5.9        9.9     19.2  2017-11-07        2.3
# 11   112  인천  12-17     -1.3        2.1     10.0  2017-12-03       -4.7
# ...

# %%
dm_wa = df.iloc[11:14, 3:4]
dm_w17 = dm_wa.mean()
dm_w17
# Out:
# 평균기온(℃)   -2.3
# dtype: float64

# %%
dm_wb = df.iloc[23:26, 3:4]
dm_w18 = dm_wb.mean()
dm_w18
# Out:
# 평균기온(℃)    0.033333
# dtype: float64

# %%
dm_wc = df.iloc[35:38, 3:4]
dm_w19 = dm_wc.mean()
dm_w19
# Out:
# 평균기온(℃)    2.1
# dtype: float64

# %%
dm_wd = df.iloc[47:50, 3:4]
dm_w20 = dm_wd.mean()
dm_w20
# Out:
# 평균기온(℃)    0.1
# dtype: float64

# %%
data = { '연도' : ['2017','2018','2019','2020'],
    '평균기온(℃)' : ['-2.3','0.033333','2.1','0.1'] ,
}

dfwm = pd.DataFrame(data)
print(dfwm)
# Out:
#      연도   평균기온(℃)
# 0  2017      -2.3
# 1  2018  0.033333
# 2  2019       2.1
# 3  2020       0.1

# %%
dfwm.to_csv("./df_winteravg.csv",index=False)

# %%
pd.read_csv('./인천광역시_코로나19 확진자 현황_20220117.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-5522b5bf39b4> in <module>
# ----> 1 pd.read_csv('./인천광역시_코로나19 확진자 현황_20220117.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
sns.pointplot(data=dfwm, x='연도', y='평균기온(℃)')
