# %%
# 불(bool) 자료형이란 참(True)과 거짓(False)을 나타내는 자료형 , True, False 만 존재
a = True
b = False

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %%
1 == 1
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
2< 1
# Out:
# False

# %%
a = [1, 2, 3, 4]
while a:
    print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %%
if []:
    print("참")
else:
    print("거짓")

# 리스트가 비어있음
# Out:
# 거짓

# %%
if [1,2,3]:
    print("참")
else:
    print("거짓")
    
# 리스트에 값이 있음
# Out:
# 참

# %%
# 불 연산
bool('python')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool([1,2,3])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(3)
# Out:
# True
