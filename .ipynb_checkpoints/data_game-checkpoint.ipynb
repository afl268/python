# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
matplotlib.rc('axes',unicode_minus = False)
matplotlib.rc('font',family = 'Malgun Gothic')

# %%
data = { '년/월' : ['2021/1','2021/2','2021/3','2021/4','2021/5','2021/6','2021/7','2021/8','2021/9',
                      '2021/10','2021/11','2021/12'],
    '매출(억)' : ['18.25','8.94','8.40','3.16','1.97','3.30','5.43','4.17','3.77','2.37','3.47','1.95'] ,
}

df= pd.DataFrame(data)
df.set_index('년/월', inplace = True)
print(df)
# Out:
#          매출(억)
# 년/월
# 2021/1   18.25
# 2021/2    8.94
# 2021/3    8.40
# 2021/4    3.16
# 2021/5    1.97
# 2021/6    3.30
# 2021/7    5.43
# 2021/8    4.17
# 2021/9    3.77
# 2021/10   2.37
# 2021/11   3.47
# 2021/12   1.95

# %%
df.to_csv("./df_21priconne")

# %%
pd.read_csv('./df_21priconne')
# Out:
#         년/월  매출(억)
# 0    2021/1  18.25
# 1    2021/2   8.94
# 2    2021/3   8.40
# 3    2021/4   3.16
# 4    2021/5   1.97
# 5    2021/6   3.30
# 6    2021/7   5.43
# 7    2021/8   4.17
# 8    2021/9   3.77
# 9   2021/10   2.37
# 10  2021/11   3.47
# 11  2021/12   1.95

# %%
plt.figure(figsize=(18,4))
sns.pointplot(data=data, x='년/월', y='매출(억)')

# %%
# 1월 매출의 이유, 이후에 무슨 일이 있었는지는 다음에
